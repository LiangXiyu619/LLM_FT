# %%
with open("test_data_locale.txt", "r", encoding="utf-8") as f:
    locales = [line.strip() for line in f]

# %% [markdown]
# # lora2

# %%
import json
from sklearn.metrics import f1_score

VALID_LABELS = {"Exact", "Substitute", "Complement", "Irrelevant"}

y_true = []
y_pred = []

with open("lora2_test_output.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        item = json.loads(line)

        ref = item["label"].strip()
        model_out = item["predict"].strip()

        # 提取第一个词
        first_word = model_out.split()[0]

        # 可选：防止异常输出污染评估
        if first_word not in VALID_LABELS:
            continue   # 或者标记为 Irrelevant / skip

        y_true.append(ref)
        y_pred.append(first_word)

# 计算 micro F1
micro_f1 = f1_score(y_true, y_pred, average="micro")

print(f"Micro F1: {micro_f1:.4f}")
print(f"Evaluated samples: {len(y_true)}")
# Out:
# Micro F1: 0.5344
# Evaluated samples: 2878

# %%
from collections import defaultdict

labels = set(y_true)
stats = {}

for label in labels:
    tp = sum((p == label and t == label) for p, t in zip(y_pred, y_true))
    fp = sum((p == label and t != label) for p, t in zip(y_pred, y_true))
    fn = sum((p != label and t == label) for p, t in zip(y_pred, y_true))
    tn = sum((p != label and t != label) for p, t in zip(y_pred, y_true))

    precision = tp / (tp + fp) if tp + fp > 0 else 0.0
    recall = tp / (tp + fn) if tp + fn > 0 else 0.0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    f1 = 2 * precision * recall / (precision + recall)

    stats[label] = {
        "precision": precision,
        "recall": recall,
        "accuracy": accuracy,
        "support": tp + fn,
        "f1": f1
    }

for k, v in stats.items():
    print(k, v)
# Out:
# Substitute {'precision': 0.5353805073431241, 'recall': 0.4112820512820513, 'accuracy': 0.6796386379430159, 'support': 975, 'f1': 0.4651972157772622}
# Complement {'precision': 0.2289156626506024, 'recall': 0.5984251968503937, 'accuracy': 0.893328700486449, 'support': 127, 'f1': 0.3311546840958606}
# Irrelevant {'precision': 0.3936899862825789, 'recall': 0.6145610278372591, 'accuracy': 0.7838776928422516, 'support': 467, 'f1': 0.479933110367893}
# Exact {'precision': 0.7247191011235955, 'recall': 0.5912910618792971, 'accuracy': 0.711952744961779, 'support': 1309, 'f1': 0.6512410601598654}

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

labels = ["Exact", "Substitute", "Complement", "Irrelevant"]

cm = confusion_matrix(y_true, y_pred, labels=labels)
df_cm = pd.DataFrame(cm, index=labels, columns=labels)

print(df_cm)
# Out:
#             Exact  Substitute  Complement  Irrelevant
# Exact         774         261         122         152
# Substitute    231         401          81         262
# Complement     18           5          76          28
# Irrelevant     45          82          53         287

# %%
from collections import defaultdict

# stats[locale][label] = correct_count
stats = defaultdict(lambda: defaultdict(int))

for loc, t, p in zip(locales, y_true, y_pred):
    if t == p:
        stats[loc][t] += 1

stats
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'es': defaultdict(int,
#                          {'Substitute': 80,
#                           'Complement': 22,
#                           'Exact': 144,
#                           'Irrelevant': 62}),
#              'us': defaultdict(int,
#                          {'Complement': 37,
#                           'Substitute': 217,
#                           'Exact': 413,
#                           'Irrelevant': 148}),
#              'jp': defaultdict(int,
#                          {'Complement': 17,
#                           'Irrelevant': 77,
#                           'Substitute': 104,
#                           'Exact': 217})})

# %%
from collections import defaultdict

# stats[locale][label] = {tp, fp, fn}
stats = defaultdict(lambda: defaultdict(lambda: {"tp": 0, "fp": 0, "fn": 0}))

labels = set(y_true)

# 1. 统计 TP / FP / FN（在每个 locale 内）
for loc, t, p in zip(locales, y_true, y_pred):
    for label in labels:
        if p == label and t == label:
            stats[loc][label]["tp"] += 1
        elif p == label and t != label:
            stats[loc][label]["fp"] += 1
        elif p != label and t == label:
            stats[loc][label]["fn"] += 1

# 2. 计算 precision / recall / f1
metrics = defaultdict(dict)

for loc, label_stats in stats.items():
    for label, c in label_stats.items():
        tp, fp, fn = c["tp"], c["fp"], c["fn"]

        precision = tp / (tp + fp) if tp + fp > 0 else 0.0
        recall    = tp / (tp + fn) if tp + fn > 0 else 0.0
        f1        = (
            2 * precision * recall / (precision + recall)
            if precision + recall > 0 else 0.0
        )

        metrics[loc][label] = {
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "support": tp + fn,
            "tp": tp,
            "fp": fp,
            "fn": fn,
        }

# %%
metrics
# Out:
# defaultdict(dict,
#             {'us': {'Substitute': {'precision': 0.48008849557522126,
#                'recall': 0.4157088122605364,
#                'f1': 0.4455852156057495,
#                'support': 522,
#                'tp': 217,
#                'fp': 235,
#                'fn': 305},
#               'Irrelevant': {'precision': 0.39361702127659576,
#                'recall': 0.5648854961832062,
#                'f1': 0.4639498432601881,
#                'support': 262,
#                'tp': 148,
#                'fp': 228,
#                'fn': 114},
#               'Exact': {'precision': 0.7132987910189983,
#                'recall': 0.5665294924554184,
#                'f1': 0.6314984709480124,
#                'support': 729,
#                'tp': 413,
#                'fp': 166,
#                'fn': 316},
#               'Complement': {'precision': 0.22289156626506024,
#                'recall': 0.6166666666666667,
#                'f1': 0.3274336283185841,
#                'support': 60,
#                'tp': 37,
#                'fp': 129,
#                'fn': 23}},
#              'es': {'Complement': {'precision': 0.2716049382716049,
#                'recall': 0.5945945945945946,
#                'f1': 0.3728813559322034,
#                'support': 37,
#                'tp': 22,
#                'fp': 59,
#                'fn': 15},
#               'Exact': {'precision': 0.7422680412371134,
#                'recall': 0.5950413223140496,
#                'f1': 0.6605504587155964,
#                'support': 242,
#                'tp': 144,
#                'fp': 50,
#                'fn': 98},
#               'Substitute': {'precision': 0.6201550387596899,
#                'recall': 0.41450777202072536,
#                'f1': 0.4968944099378882,
#                'support': 193,
#                'tp': 80,
#                'fp': 49,
#                'fn': 113},
#               'Irrelevant': {'precision': 0.3924050632911392,
#                'recall': 0.6888888888888889,
#                'f1': 0.4999999999999999,
#                'support': 90,
#                'tp': 62,
#                'fp': 96,
#                'fn': 28}},
#              'jp': {'Substitute': {'precision': 0.6190476190476191,
#                'recall': 0.4,
#                'f1': 0.485981308411215,
#                'support': 260,
#                'tp': 104,
#                'fp': 64,
#                'fn': 156},
#               'Exact': {'precision': 0.735593220338983,
#                'recall': 0.6420118343195266,
#                'f1': 0.6856240126382305,
#                'support': 338,
#                'tp': 217,
#                'fp': 78,
#                'fn': 121},
#               'Complement': {'precision': 0.2,
#                'recall': 0.5666666666666667,
#                'f1': 0.29565217391304355,
#                'support': 30,
#                'tp': 17,
#                'fp': 68,
#                'fn': 13},
#               'Irrelevant': {'precision': 0.39487179487179486,
#                'recall': 0.6695652173913044,
#                'f1': 0.4967741935483871,
#                'support': 115,
#                'tp': 77,
#                'fp': 118,
#                'fn': 38}}})

# %% [markdown]
# # lora1

# %%
import json
from sklearn.metrics import f1_score

VALID_LABELS = {"Exact", "Substitute", "Complement", "Irrelevant"}

y_true = []
y_pred = []

with open("lora1_test_output.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        item = json.loads(line)

        ref = item["label"].strip()
        model_out = item["predict"].strip()

        # 提取第一个词
        first_word = model_out.split()[0]

        # 可选：防止异常输出污染评估
        if first_word not in VALID_LABELS:
            continue   # 或者标记为 Irrelevant / skip

        y_true.append(ref)
        y_pred.append(first_word)

# 计算 micro F1
micro_f1 = f1_score(y_true, y_pred, average="micro")

print(f"Micro F1: {micro_f1:.4f}")
print(f"Evaluated samples: {len(y_true)}")
# Out:
# Micro F1: 0.4868
# Evaluated samples: 2880

# %%
y_true
# Out:
# ['Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  ...]

# %%
y_pred
# Out:
# ['Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Complement',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Complement',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Irrelevant',
#  'Irrelevant',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Complement',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Complement',
#  'Substitute',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Substitute',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Irrelevant',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  'Exact',
#  'Exact',
#  'Irrelevant',
#  'Exact',
#  'Complement',
#  'Irrelevant',
#  ...]

# %%
from collections import defaultdict

labels = set(y_true)
stats = {}

for label in labels:
    tp = sum((p == label and t == label) for p, t in zip(y_pred, y_true))
    fp = sum((p == label and t != label) for p, t in zip(y_pred, y_true))
    fn = sum((p != label and t == label) for p, t in zip(y_pred, y_true))
    tn = sum((p != label and t != label) for p, t in zip(y_pred, y_true))

    precision = tp / (tp + fp) if tp + fp > 0 else 0.0
    recall = tp / (tp + fn) if tp + fn > 0 else 0.0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    f1 = 2 * precision * recall / (precision + recall)

    stats[label] = {
        "precision": precision,
        "recall": recall,
        "accuracy": accuracy,
        "support": tp + fn,
        "f1": f1
    }

for k, v in stats.items():
    print(k, v)
# Out:
# Substitute {'precision': 0.6877828054298643, 'recall': 0.1558974358974359, 'accuracy': 0.6902777777777778, 'support': 975, 'f1': 0.25418060200668896}
# Complement {'precision': 0.17829457364341086, 'recall': 0.5433070866141733, 'accuracy': 0.8694444444444445, 'support': 127, 'f1': 0.2684824902723736}
# Irrelevant {'precision': 0.33513513513513515, 'recall': 0.7965738758029979, 'accuracy': 0.7107638888888889, 'support': 467, 'f1': 0.4717818642993025}
# Exact {'precision': 0.6962134251290878, 'recall': 0.6170861937452327, 'accuracy': 0.703125, 'support': 1311, 'f1': 0.6542660735948241}

# %%
TP = sum((p == t) for p, t in zip(y_pred, y_true))
FP = sum((p != t) for p, t in zip(y_pred, y_true))
FN = FP  # single-label multi-class 下 FP == FN

micro_precision = TP / (TP + FP) if (TP + FP) > 0 else 0.0
micro_recall    = TP / (TP + FN) if (TP + FN) > 0 else 0.0
micro_f1        = (2 * micro_precision * micro_recall /
                   (micro_precision + micro_recall)
                   if (micro_precision + micro_recall) > 0 else 0.0)

print("micro_precision:", micro_precision)
print("micro_recall   :", micro_recall)
print("micro_f1       :", micro_f1)
# Out:
# micro_precision: 0.48680555555555555
# micro_recall   : 0.48680555555555555
# micro_f1       : 0.48680555555555555

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

labels = ["Exact", "Substitute", "Complement", "Irrelevant"]

cm = confusion_matrix(y_true, y_pred, labels=labels)
df_cm = pd.DataFrame(cm, index=labels, columns=labels)

print(df_cm)
# Out:
#             Exact  Substitute  Complement  Irrelevant
# Exact         809          55         165         282
# Substitute    292         152         115         416
# Complement     17           1          69          40
# Irrelevant     44          13          38         372

# %%
from collections import defaultdict

# stats[locale][label] = correct_count
stats = defaultdict(lambda: defaultdict(int))

for loc, t, p in zip(locales, y_true, y_pred):
    if t == p:
        stats[loc][t] += 1

stats
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'jp': defaultdict(int,
#                          {'Exact': 223,
#                           'Irrelevant': 101,
#                           'Complement': 17,
#                           'Substitute': 48}),
#              'us': defaultdict(int,
#                          {'Exact': 457,
#                           'Irrelevant': 197,
#                           'Substitute': 56,
#                           'Complement': 28}),
#              'es': defaultdict(int,
#                          {'Complement': 24,
#                           'Exact': 129,
#                           'Substitute': 48,
#                           'Irrelevant': 74})})

# %%
from collections import defaultdict

# stats[locale][label] = {tp, fp, fn}
stats = defaultdict(lambda: defaultdict(lambda: {"tp": 0, "fp": 0, "fn": 0}))

labels = set(y_true)

# 1. 统计 TP / FP / FN（在每个 locale 内）
for loc, t, p in zip(locales, y_true, y_pred):
    for label in labels:
        if p == label and t == label:
            stats[loc][label]["tp"] += 1
        elif p == label and t != label:
            stats[loc][label]["fp"] += 1
        elif p != label and t == label:
            stats[loc][label]["fn"] += 1

# 2. 计算 precision / recall / f1
metrics = defaultdict(dict)

for loc, label_stats in stats.items():
    for label, c in label_stats.items():
        tp, fp, fn = c["tp"], c["fp"], c["fn"]

        precision = tp / (tp + fp) if tp + fp > 0 else 0.0
        recall    = tp / (tp + fn) if tp + fn > 0 else 0.0
        f1        = (
            2 * precision * recall / (precision + recall)
            if precision + recall > 0 else 0.0
        )

        metrics[loc][label] = {
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "support": tp + fn,
            "tp": tp,
            "fp": fp,
            "fn": fn,
        }

# %%
metrics
# Out:
# defaultdict(dict,
#             {'us': {'Substitute': {'precision': 0.5957446808510638,
#                'recall': 0.10666666666666667,
#                'f1': 0.18093699515347336,
#                'support': 525,
#                'tp': 56,
#                'fp': 38,
#                'fn': 469},
#               'Irrelevant': {'precision': 0.3294314381270903,
#                'recall': 0.7943548387096774,
#                'f1': 0.46572104018912525,
#                'support': 248,
#                'tp': 197,
#                'fp': 401,
#                'fn': 51},
#               'Exact': {'precision': 0.677037037037037,
#                'recall': 0.6134228187919463,
#                'f1': 0.643661971830986,
#                'support': 745,
#                'tp': 457,
#                'fp': 218,
#                'fn': 288},
#               'Complement': {'precision': 0.13526570048309178,
#                'recall': 0.5,
#                'f1': 0.2129277566539924,
#                'support': 56,
#                'tp': 28,
#                'fp': 179,
#                'fn': 28}},
#              'es': {'Complement': {'precision': 0.2696629213483146,
#                'recall': 0.5714285714285714,
#                'f1': 0.366412213740458,
#                'support': 42,
#                'tp': 24,
#                'fp': 65,
#                'fn': 18},
#               'Exact': {'precision': 0.6861702127659575,
#                'recall': 0.589041095890411,
#                'f1': 0.6339066339066339,
#                'support': 219,
#                'tp': 129,
#                'fp': 59,
#                'fn': 90},
#               'Substitute': {'precision': 0.8135593220338984,
#                'recall': 0.2376237623762376,
#                'f1': 0.367816091954023,
#                'support': 202,
#                'tp': 48,
#                'fp': 11,
#                'fn': 154},
#               'Irrelevant': {'precision': 0.32599118942731276,
#                'recall': 0.74,
#                'f1': 0.4525993883792048,
#                'support': 100,
#                'tp': 74,
#                'fp': 153,
#                'fn': 26}},
#              'jp': {'Exact': {'precision': 0.745819397993311,
#                'recall': 0.6426512968299711,
#                'f1': 0.6904024767801857,
#                'support': 347,
#                'tp': 223,
#                'fp': 76,
#                'fn': 124},
#               'Complement': {'precision': 0.18681318681318682,
#                'recall': 0.5862068965517241,
#                'f1': 0.2833333333333333,
#                'support': 29,
#                'tp': 17,
#                'fp': 74,
#                'fn': 12},
#               'Irrelevant': {'precision': 0.3543859649122807,
#                'recall': 0.8487394957983193,
#                'f1': 0.5,
#                'support': 119,
#                'tp': 101,
#                'fp': 184,
#                'fn': 18},
#               'Substitute': {'precision': 0.7058823529411765,
#                'recall': 0.1935483870967742,
#                'f1': 0.3037974683544304,
#                'support': 248,
#                'tp': 48,
#                'fp': 20,
#                'fn': 200}}})

# %% [markdown]
# # base + think

# %%
import json
from sklearn.metrics import f1_score

VALID_LABELS = {"Exact", "Substitute", "Complement", "Irrelevant"}

y_true_bsl = []
y_pred_bsl = []

with open("baseline_test_output.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        item = json.loads(line)

        ref = item["label"].strip()
        model_out = item["predict"]

        label = None

        # case 1: 有完整 <think>...</think>
        if "<think>" in model_out and "</think>" in model_out:
            after_think = model_out.split("</think>", 1)[1].lstrip("\n")
            label = after_think.split()[0] if after_think.split() else None

        # case 2: 没有 thinking，取最后一个合法标签
        if label not in VALID_LABELS:
            for word in reversed(model_out.split()):
                if word in VALID_LABELS:
                    label = word
                    break
        
        if label not in VALID_LABELS:
            label = 'Irrelevant'

        y_true_bsl.append(ref)
        y_pred_bsl.append(label)

# 计算 micro F1
micro_f1_bsl = f1_score(y_true_bsl, y_pred_bsl, average="micro")

print(f"Micro F1: {micro_f1_bsl:.4f}")
print(f"Evaluated samples: {len(y_true_bsl)}")
# Out:
# Micro F1: 0.5160
# Evaluated samples: 2880

# %%
from collections import defaultdict

labels = set(y_true_bsl)
stats_bsl = {}

for label in labels:
    tp = sum((p == label and t == label) for p, t in zip(y_pred_bsl, y_true_bsl))
    fp = sum((p == label and t != label) for p, t in zip(y_pred_bsl, y_true_bsl))
    fn = sum((p != label and t == label) for p, t in zip(y_pred_bsl, y_true_bsl))
    tn = sum((p != label and t != label) for p, t in zip(y_pred_bsl, y_true_bsl))

    precision = tp / (tp + fp) if tp + fp > 0 else 0.0
    recall = tp / (tp + fn) if tp + fn > 0 else 0.0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    f1 = 2 * precision * recall / (precision + recall)

    stats_bsl[label] = {
        "precision": precision,
        "recall": recall,
        "accuracy": accuracy,
        "support": tp + fn,
        "f1": f1
    }

for k, v in stats_bsl.items():
    print(k, v)
# Out:
# Substitute {'precision': 0.5242718446601942, 'recall': 0.27692307692307694, 'accuracy': 0.6701388888888888, 'support': 975, 'f1': 0.3624161073825503}
# Complement {'precision': 0.36666666666666664, 'recall': 0.3464566929133858, 'accuracy': 0.9447916666666667, 'support': 127, 'f1': 0.35627530364372473}
# Irrelevant {'precision': 0.3065134099616858, 'recall': 0.6852248394004282, 'accuracy': 0.6975694444444445, 'support': 467, 'f1': 0.4235605559232296}
# Exact {'precision': 0.7094088259783514, 'recall': 0.6498855835240275, 'accuracy': 0.7194444444444444, 'support': 1311, 'f1': 0.6783439490445861}

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

labels = ["Exact", "Substitute", "Complement", "Irrelevant"]

cm = confusion_matrix(y_true_bsl, y_pred_bsl, labels=labels)
df_cm = pd.DataFrame(cm, index=labels, columns=labels)

print(df_cm)
# Out:
#             Exact  Substitute  Complement  Irrelevant
# Exact         852         167          30         262
# Substitute    259         270          27         419
# Complement     24          16          44          43
# Irrelevant     66          62          19         320

# %%
TP = sum((p == t) for p, t in zip(y_pred_bsl, y_true_bsl))
FP = sum((p != t) for p, t in zip(y_pred_bsl, y_true_bsl))
FN = FP  # single-label multi-class 下 FP == FN

micro_precision = TP / (TP + FP) if (TP + FP) > 0 else 0.0
micro_recall    = TP / (TP + FN) if (TP + FN) > 0 else 0.0
micro_f1        = (2 * micro_precision * micro_recall /
                   (micro_precision + micro_recall)
                   if (micro_precision + micro_recall) > 0 else 0.0)

print("micro_precision:", micro_precision)
print("micro_recall   :", micro_recall)
print("micro_f1       :", micro_f1)
# Out:
# micro_precision: 0.5159722222222223
# micro_recall   : 0.5159722222222223
# micro_f1       : 0.5159722222222223

# %%
from collections import defaultdict

# stats[locale][label] = correct_count
stats_bsl = defaultdict(lambda: defaultdict(int))

for loc, t, p in zip(locales, y_true_bsl, y_pred_bsl):
    if t == p:
        stats_bsl[loc][t] += 1

stats_bsl
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'jp': defaultdict(int,
#                          {'Exact': 248,
#                           'Complement': 8,
#                           'Irrelevant': 88,
#                           'Substitute': 54}),
#              'us': defaultdict(int,
#                          {'Exact': 464,
#                           'Substitute': 155,
#                           'Irrelevant': 164,
#                           'Complement': 19}),
#              'es': defaultdict(int,
#                          {'Substitute': 61,
#                           'Complement': 17,
#                           'Exact': 140,
#                           'Irrelevant': 68})})

# %%
from collections import defaultdict

# stats[locale][label] = {tp, fp, fn}
stats = defaultdict(lambda: defaultdict(lambda: {"tp": 0, "fp": 0, "fn": 0}))

labels = set(y_true_bsl)

# 1. 统计 TP / FP / FN（在每个 locale 内）
for loc, t, p in zip(locales, y_true_bsl, y_pred_bsl):
    for label in labels:
        if p == label and t == label:
            stats[loc][label]["tp"] += 1
        elif p == label and t != label:
            stats[loc][label]["fp"] += 1
        elif p != label and t == label:
            stats[loc][label]["fn"] += 1

# 2. 计算 precision / recall / f1
metrics = defaultdict(dict)

for loc, label_stats in stats.items():
    for label, c in label_stats.items():
        tp, fp, fn = c["tp"], c["fp"], c["fn"]

        precision = tp / (tp + fp) if tp + fp > 0 else 0.0
        recall    = tp / (tp + fn) if tp + fn > 0 else 0.0
        f1        = (
            2 * precision * recall / (precision + recall)
            if precision + recall > 0 else 0.0
        )

        metrics[loc][label] = {
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "support": tp + fn,
            "tp": tp,
            "fp": fp,
            "fn": fn,
        }

# %%
metrics
# Out:
# defaultdict(dict,
#             {'us': {'Substitute': {'precision': 0.4889589905362776,
#                'recall': 0.29523809523809524,
#                'f1': 0.3681710213776722,
#                'support': 525,
#                'tp': 155,
#                'fp': 162,
#                'fn': 370},
#               'Irrelevant': {'precision': 0.3048327137546468,
#                'recall': 0.6612903225806451,
#                'f1': 0.41730279898218825,
#                'support': 248,
#                'tp': 164,
#                'fp': 374,
#                'fn': 84},
#               'Exact': {'precision': 0.7171561051004637,
#                'recall': 0.6228187919463087,
#                'f1': 0.6666666666666666,
#                'support': 745,
#                'tp': 464,
#                'fp': 183,
#                'fn': 281},
#               'Complement': {'precision': 0.2638888888888889,
#                'recall': 0.3392857142857143,
#                'f1': 0.29687499999999994,
#                'support': 56,
#                'tp': 19,
#                'fp': 53,
#                'fn': 37}},
#              'es': {'Complement': {'precision': 0.6071428571428571,
#                'recall': 0.40476190476190477,
#                'f1': 0.4857142857142857,
#                'support': 42,
#                'tp': 17,
#                'fp': 11,
#                'fn': 25},
#               'Exact': {'precision': 0.6666666666666666,
#                'recall': 0.639269406392694,
#                'f1': 0.6526806526806527,
#                'support': 219,
#                'tp': 140,
#                'fp': 70,
#                'fn': 79},
#               'Substitute': {'precision': 0.580952380952381,
#                'recall': 0.30198019801980197,
#                'f1': 0.3973941368078176,
#                'support': 202,
#                'tp': 61,
#                'fp': 44,
#                'fn': 141},
#               'Irrelevant': {'precision': 0.3090909090909091,
#                'recall': 0.68,
#                'f1': 0.425,
#                'support': 100,
#                'tp': 68,
#                'fp': 152,
#                'fn': 32}},
#              'jp': {'Exact': {'precision': 0.7209302325581395,
#                'recall': 0.7146974063400576,
#                'f1': 0.7178002894356005,
#                'support': 347,
#                'tp': 248,
#                'fp': 96,
#                'fn': 99},
#               'Complement': {'precision': 0.4,
#                'recall': 0.27586206896551724,
#                'f1': 0.32653061224489793,
#                'support': 29,
#                'tp': 8,
#                'fp': 12,
#                'fn': 21},
#               'Substitute': {'precision': 0.5806451612903226,
#                'recall': 0.21774193548387097,
#                'f1': 0.3167155425219942,
#                'support': 248,
#                'tp': 54,
#                'fp': 39,
#                'fn': 194},
#               'Irrelevant': {'precision': 0.3076923076923077,
#                'recall': 0.7394957983193278,
#                'f1': 0.4345679012345679,
#                'support': 119,
#                'tp': 88,
#                'fp': 198,
#                'fn': 31}}})
